# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <img src="./ex1.JPG">
#
# First of all I import csv files extracted from the excel sheet.

# %%
df_cc = pd.read_csv("./SONY_Exercise_1 - Customer claim.csv", index_col = 'CustomerNR' )
df_sap = pd.read_csv("./SONY_Exercise_1 - SAP.csv",index_col = 'Customer nr.')

# %% [markdown]
# After that, we define a function in order to check discrepancies.

# %%
def compensation_test(customer_claim,sap):
    customer_claims_ids = customer_claim.groupby(customer_claim.index)['QTY to compensate','End stock/Sellin'].sum()
    sap_ids = sap.groupby(sap.index)['Processed quantity'].sum()
    not_compensated = [(sap_id,"not_compensated") for sap_id in sap_ids.index if sap_id not in customer_claims_ids.index ]
    overcompensated =  [(customer_claims_id,'overcompensated') for customer_claims_id in customer_claims_ids.index if customer_claims_id not in sap_ids.index]
    wrong_claims = [(customer_claim_id,'wrong_claim') for customer_claim_id in customer_claims_ids.index if (customer_claims_ids.loc[customer_claim_id]['QTY to compensate'] - sap_ids.loc[customer_claim_id] != 0)]
    suspicious_compensations =  not_compensated + overcompensated + wrong_claims
    return  suspicious_compensations

# %%
compensation_test(df_cc,df_sap)
# Out:
# [(271500357, 'not_compensated'), (272500650, 'wrong_claim')]

# %% [markdown]
# Two discrepancies:
# - -271500357 doesn't exist on customer claim sheet.
# - -272500650 Claimed one unit more than corresponding on SAP registry.

# %% [markdown]
# <img src="./ex2.JPG">
#
# First of all I import csv files extracted from the excel sheet.

# %%
df_ac = pd.read_csv("./SONY_Exercise_2 - Amounts to be compensated.csv",index_col = 'Model name' )
df_bq = pd.read_csv("./SONY_Exercise_2 - Billing qtys.csv",index_col = 'Material')

# %% [markdown]
# I define a function in order to calculate the costs.

# %%
def calculate_total_amount(amount_compensated,billing_quantitys):
    billing_quantitys['amount'] = [ amount_compensated.loc[index]['Amount/PC (CZK)']*qty for (index,qty) in zip(billing_quantitys.index,billing_quantitys['Bill qty'])]
    grouped_billing_quantitys = billing_quantitys.groupby(billing_quantitys.Name)['amount'].sum()
    return grouped_billing_quantitys,grouped_billing_quantitys.sum()

# %%
calculate_total_amount(df_ac,df_bq)
# Out:
# (Name
#  AT COMPUTERS A.S.               8852
#  Aaron shop s.r.o.              18620
#  BER-KR SERVICES S.R.O.          4767
#  CEWE COLOR a.s.                15820
#  ELLEX GK S.R.O.                 5497
#  Elvia pro, spol. s r.o.        16348
#  MEGAPIXEL S.R.O.               20732
#  Milan Skoda-FOTO               19556
#  SWS A.S.                        8104
#  VIDEO klinik, spol. s r. o.     1424
#  Name: amount, dtype: int64, 119720)

# %% [markdown]
# Total costs is 119720

# %% [markdown]
# <img src="./ex3.JPG">
#
# First of all I import csv file extracted from the excel sheet.

# %%
df_fy = pd.read_csv("./SONY_Exercise_3 - FY13 Sept-March DI.csv",index_col = 'Bill.Doc.')

# %% [markdown]
# I parse 'bill date' colum to datetime type.

# %%
df_fy['date'] = pd.to_datetime(df_fy['Bill. Date'])

# %% [markdown]
# now we calculate the amount of bills on 2013-12-20

# %%
ondate = df_fy.loc[df_fy['date'] == '2013-12-20']

# %%
ondate
# Out:
#             Item       Material  MPG  Billed qty  CnTy     Amount  CondRecNo.  \
# Bill.Doc.
# 6876100217   260    SLTA58K.CEC  NaN           2  ZNET        130         NaN
# 6876100218   120  DSCHX300B.CE3  NaN           2  ZNET         70         NaN
# 6876100219    60   DSCHX50B.CE3  NaN           1  ZNET         60         NaN
# 6876100220    70   DSCHX50S.CE3  NaN           2  ZNET         60         NaN
# 6876100221   150    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100222   110  DSCRX100.CEE8  NaN           1  ZNET        163         NaN
# 6876100223    50  DSCRX100.CEE8  NaN           1  ZNET        163         NaN
# 6876100224    40  DSCWX200B.CE3  NaN           2  ZNET         50         NaN
# 6876100225    60  DSCWX200B.CE3  NaN           2  ZNET         50         NaN
# 6876100226   110  DSCWX200S.CE3  NaN           2  ZNET         50         NaN
# 6876100227   160  DSCWX200S.CE3  NaN           1  ZNET         50         NaN
# 6876100228    90   DSCHX50B.CE3  NaN           2  ZNET         60         NaN
# 6876100229   120  DSCWX300B.CE3  NaN           1  ZNET         60         NaN
# 6876100230   180  DSCWX300L.CE3  NaN           1  ZNET         60         NaN
# 6876100231   130  DSCHX300B.CE3  NaN           7  ZNET         70         NaN
# 6876100232   280  DSCHX300B.CE3  NaN           1  ZNET         70         NaN
# 6876100233    10    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100234    40    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100235    10  DSCHX300B.CE3  NaN           2  ZNET         70         NaN
# 6876100236    30   DSCHX50B.CE3  NaN           1  ZNET         60         NaN
# 6876100237    40  DSCWX300B.CE3  NaN           1  ZNET         60         NaN
# 6876100239    10    SLTA58K.CEC  NaN           3  ZNET        130         NaN
# 6876100240   150  DSCWX200B.CE3  NaN           1  ZNET         50         NaN
# 6876100241    10  DSCHX300B.CE3  NaN           3  ZNET         70         NaN
# 6876100242    40  DSCHX300B.CE3  NaN           2  ZNET         70         NaN
# 6876100243    50   DSCHX50B.CE3  NaN           2  ZNET         60         NaN
# 6876100244    60  DSCWX300B.CE3  NaN           1  ZNET         60         NaN
# 6876100245    20  DSCWX300L.CE3  NaN           1  ZNET         60         NaN
# 6876100246    70  DSCWX300W.CE3  NaN           1  ZNET         60         NaN
# 6876100247   170    SLTA58K.CEC  NaN           2  ZNET        130         NaN
# ...          ...            ...  ...         ...   ...        ...         ...
# 6876100688    30  DSCWX200S.CE3  NaN           1  ZNET         50         NaN
# 6876100689    10   DSCHX50B.CE3  NaN           3  ZNET         60         NaN
# 6876100690    20   DSCHX50B.CE3  NaN           1  ZNET         60         NaN
# 6876100691    10   DSCHX50S.CE3  NaN           2  ZNET         60         NaN
# 6876100692   110  DSCWX300B.CE3  NaN           2  ZNET         60         NaN
# 6876100693   130  DSCWX300L.CE3  NaN           1  ZNET         60         NaN
# 6876100694    40  DSCHX300B.CE3  NaN           1  ZNET         70         NaN
# 6876100695   150  DSCHX300B.CE3  NaN           1  ZNET         70         NaN
# 6876100696    10    SLTA58K.CEC  NaN           2  ZNET        130         NaN
# 6876100697    60    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100698    50  DSCRX100.CEE8  NaN           1  ZNET        163         NaN
# 6876100699    90  DSCWX300B.CE3  NaN           1  ZNET         60         NaN
# 6876100700   110  DSCWX300L.CE3  NaN           2  ZNET         60         NaN
# 6876100701   250  DSCHX300B.CE3  NaN           1  ZNET         70         NaN
# 6876100702    50    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100703    50  DSCRX100.CEE8  NaN           1  ZNET        163         NaN
# 6876100704    10   DSCHX50B.CE3  NaN           1  ZNET         60         NaN
# 6876100705    40    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100706   857  DSCHX300B.CE3  NaN           2  ZNET         70         NaN
# 6876100755    10    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100756    90    SLTA58K.CEC  NaN           1  ZNET        130         NaN
# 6876100757    80  DSCWX200B.CE3  NaN           1  ZNET         50         NaN
# 6876100757    90  DSCWX200S.CE3  NaN           2  ZNET         50         NaN
# 6876100758    30   DSCHX50B.CE3  NaN           3  ZNET         60         NaN
# 6876100759   110  DSCWX300B.CE3  NaN           1  ZNET         60         NaN
# 6876100760    40  DSCWX300L.CE3  NaN           1  ZNET         60         NaN
# 6876100761    20  DSCWX300W.CE3  NaN           1  ZNET         60         NaN
# 6876100762    30  DSCHX300B.CE3  NaN           7  ZNET         70         NaN
# 6876100763    70  DSCHX300B.CE3  NaN           1  ZNET         70         NaN
# 6876100764   140  DSCHX300B.CE3  NaN           1  ZNET         70         NaN
#
#             Agreement   Cond.value SOff.    ...       Product hierarchy  \
# Bill.Doc.                                   ...
# 6876100217        NaN          260  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100218        NaN          140  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100219        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100220        NaN          120  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100221        NaN          130  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100222        NaN          163  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100223        NaN          163  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100224        NaN          100  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100225        NaN          100  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100226        NaN          100  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100227        NaN           50  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100228        NaN          120  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100229        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100230        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100231        NaN          490  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100232        NaN           70  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100233        NaN          130  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100234        NaN          130  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100235        NaN          140  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100236        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100237        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100239        NaN          390  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100240        NaN           50  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100241        NaN          210  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100242        NaN          140  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100243        NaN          120  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100244        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100245        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100246        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100247        NaN          260  PL00    ...      SCPCDIMAMCDSLRDSLR
# ...               ...          ...   ...    ...                     ...
# 6876100688        NaN           50  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100689        NaN          180  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100690        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100691        NaN          120  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100692        NaN          120  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100693        NaN           60  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100694        NaN           70  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100695        NaN           70  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876100696        NaN          260  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100697        NaN          130  PL00    ...      SCPCDIMAMCDSLRDSLR
# 6876100698        NaN          163  PL00    ...      SCPCDIMDSCCYBRCYBS
# 6876
# 6876100230  sell out support-MSH  12.06.2013 2013-12-20
# 6876100231  sell out support-MSH  10.04.2013 2013-12-20
# 6876100232  sell out support-MSH  10.04.2013 2013-12-20
# 6876100233  sell out support-MSH  10.04.2013 2013-12-20
# 6876100234  sell out support-MSH  10.04.2013 2013-12-20
# 6876100235  sell out support-MSH  13.03.2013 2013-12-20
# 6876100236  sell out support-MSH  13.05.2013 2013-12-20
# 6876100237  sell out support-MSH  13.05.2013 2013-12-20
# 6876100239  sell out support-MSH  10.04.2013 2013-12-20
# 6876100240  sell out support-MSH  15.01.2013 2013-12-20
# 6876100241  sell out support-MSH  10.05.2013 2013-12-20
# 6876100242  sell out support-MSH  04.06.2013 2013-12-20
# 6876100243  sell out support-MSH  10.05.2013 2013-12-20
# 6876100244  sell out support-MSH  10.05.2013 2013-12-20
# 6876100245  sell out support-MSH  12.06.2013 2013-12-20
# 6876100246  sell out support-MSH  05.06.2013 2013-12-20
# 6876100247  sell out support-MSH  10.04.2013 2013-12-20
# ...                          ...         ...        ...
# 6876100688  sell out support-MSH  13.02.2013 2013-12-20
# 6876100689  sell out support-MSH  30.04.2013 2013-12-20
# 6876100690  sell out support-MSH  17.06.2013 2013-12-20
# 6876100691  sell out support-MSH  13.08.2013 2013-12-20
# 6876100692  sell out support-MSH  13.05.2013 2013-12-20
# 6876100693  sell out support-MSH  26.06.2013 2013-12-20
# 6876100694  sell out support-MSH  09.04.2013 2013-12-20
# 6876100695  sell out support-MSH  22.04.2013 2013-12-20
# 6876100696  sell out support-MSH  10.04.2013 2013-12-20
# 6876100697  sell out support-MSH  29.04.2013 2013-12-20
# 6876100698  sell out support-MSH  15.11.2012 2013-12-20
# 6876100699  sell out support-MSH  13.05.2013 2013-12-20
# 6876100700  sell out support-MSH  22.07.2013 2013-12-20
# 6876100701  sell out support-MSH  15.05.2013 2013-12-20
# 6876100702  sell out support-MSH  12.04.2013 2013-12-20
# 6876100703  sell out support-MSH  31.01.2013 2013-12-20
# 6876100704  sell out support-MSH  30.04.2013 2013-12-20
# 6876100705  sell out support-MSH  10.10.2013 2013-12-20
# 6876100706  sell out support-MSH  03.10.2013 2013-12-20
# 6876100755  sell out support-MSH  10.04.2013 2013-12-20
# 6876100756  sell out support-MSH  10.04.2013 2013-12-20
# 6876100757  sell out support-MSH  07.02.2013 2013-12-20
# 6876100757  sell out support-MSH  07.02.2013 2013-12-20
# 6876100758  sell out support-MSH  13.05.2013 2013-12-20
# 6876100759  sell out support-MSH  10.05.2013 2013-12-20
# 6876100760  sell out support-MSH  26.06.2013 2013-12-20
# 6876100761  sell out support-MSH  05.06.2013 2013-12-20
# 6876100762  sell out support-MSH  29.07.2013 2013-12-20
# 6876100763  sell out support-MSH  12.09.2013 2013-12-20
# 6876100764  sell out support-MSH  01.10.2013 2013-12-20
#
# [481 rows x 28 columns]

# %% [markdown]
# 481 invoices were created on 20th of December of 2013

# %% [markdown]
# krakow_invoices = df_fy.loc[df_fy['Name 1'] == 'Neonet S.A. Krakow']
